# %% [markdown]
# # Exploratory Data Analysis (EDA) and XAI Plots
#
# This notebook is used for initial EDA and testing XAI (Explainable AI) visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap

# %% [markdown]
# ## Load Data

# %%
# Load the merged dataset
df = pd.read_csv('../data/master_dataset.csv')
print(f"Dataset shape: {df.shape}")
print(df.head())

# %% [markdown]
# ## Initial EDA

# %%
# Add your exploratory analysis here
print(df.info())
print(df.describe())

# %% [markdown]
# ## SHAP Explanations

# %%
# Load model and generate SHAP values
# This section will be populated after model training
